# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'D:\\Gene_Project\\Refined_Codes'

# %%
# updated_data_supervised = pd.read_csv(r"D://Gene_Project//pul_seq_low_high_substr_year_corrected.csv")

# %%
updated_data_supervised = pd.read_csv(r"D://Gene_Project//all_unsupervised_genes.csv")

# %%
updated_data_supervised
# Out:
#                                                  sequence
# 0                                        1.A.72,MerR,GH23
# 1                                               3.A.1,CE4
# 2       3.A.23,9.A.5,MCPsignal,2.A.21,2.A.22,TetR_N,3....
# 3                             CE4,8.A.5,3.A.1,3.A.1,3.A.1
# 4                   GT51,Peripla_BP_2,3.A.1,3.A.1,9.B.169
# ...                                                   ...
# 240617  3.A.23,GH23,1.B.1,Sigma70_r2|Sigma70_r4_2,FecR...
# 240618  3.A.1,3.A.1,3.A.1,3.A.1,1.B.48,Pyr_redox_2,1.B...
# 240619  9.B.145,HTH_1|LysR_substrate,2.A.1,3.A.1,3.A.1...
# 240620  1.B.12,Peripla_BP_3|LacI,3.A.1,SBP_bac_1,3.A.1...
# 240621  GT25,Rhodanese,3.A.3,9.B.105,2.A.1,9.B.27,3.A....
#
# [240622 rows x 1 columns]

# %%
gene_list = [seq.replace("|", ",").split(",") for seq in updated_data_supervised["sequence"]]

# %%
import numpy as np

# %%
len(np.unique([gene for seq in gene_list for gene in seq]))
# Out:
# 1399

# %%
from collections import Counter

# %%
gene_count = Counter([gene for seq in gene_list for gene in seq])

# %%
# sort in descending order
D =dict(sorted(gene_count.items(), key=lambda item: item[1], reverse = True))

# manipulate for plotting
first2pairs = {k: D[k] for k in list(D)}

# variable assignment
D = first2pairs

# %%
D
# Out:
# {'3.A.1': 445283,
#  '2.A.1': 86993,
#  'GT2': 63177,
#  'GT4': 51694,
#  'Response_reg': 47633,
#  'HTH_1': 35098,
#  'LysR_substrate': 34217,
#  'HATPase_c': 32140,
#  '1.B.14': 30074,
#  '2.A.6': 30034,
#  'HTH_18': 30022,
#  'LacI': 27823,
#  'Peripla_BP_3': 26545,
#  '3.D.1': 23750,
#  'GntR': 21481,
#  '3.A.23': 21451,
#  'HisKA': 21220,
#  '2.A.7': 21112,
#  'TetR_N': 19234,
#  '9.B.34': 18879,
#  'Aminotran_1_2': 18840,
#  '4.C.1': 17277,
#  '2.A.3': 17144,
#  '2.A.21': 16753,
#  'Trans_reg_C': 15767,
#  '1.B.52': 15574,
#  'GerE': 15035,
#  '4.A.3': 14725,
#  '9.B.18': 14724,
#  '4.A.1': 14310,
#  'GH23': 14259,
#  '3.A.6': 13979,
#  'PfkB': 13797,
#  'Pyr_redox_2': 13724,
#  '5.A.3': 13497,
#  '3.A.7': 13481,
#  'GH1': 13152,
#  '3.A.3': 12936,
#  'MarR': 12691,
#  'SBP_bac_1': 12648,
#  'GH3': 12597,
#  'AraC_binding': 12568,
#  '3.A.2': 12448,
#  '2.A.66': 12110,
#  '4.A.2': 11490,
#  '8.A.5': 11374,
#  'GT51': 11271,
#  'SIS': 11196,
#  '3.D.4': 11105,
#  'HTH_3': 10880,
#  '1.A.30': 10515,
#  '4.A.6': 10296,
#  'Sigma70_r2': 10134,
#  'GH2': 9472,
#  'CE4': 9317,
#  '2.A.56': 9090,
#  '3.A.15': 8573,
#  '8.A.3': 8415,
#  '2.A.2': 8384,
#  'PAS': 8255,
#  'CBM50': 8116,
#  'GT9': 8037,
#  'EAL': 7800,
#  'GT0': 7701,
#  'Sigma70_r4_2': 7661,
#  'NUDIX': 7491,
#  '3.A.5': 7415,
#  'Peripla_BP_1': 7106,
#  '2.A.23': 6874,
#  '8.A.59': 6789,
#  'CBM48': 6743,
#  '2.A.40': 6404,
#  'HTH_DeoR': 6312,
#  'Glyoxalase': 6276,
#  'GH73': 6139,
#  'GH32': 6034,
#  '1.A.23': 5997,
#  '8.A.1': 5920,
#  'GGDEF': 5866,
#  'MerR': 5862,
#  'HTH_IclR': 5833,
#  'CBM32': 5759,
#  'GH18': 5754,
#  'DeoRC': 5657,
#  'GH4': 5621,
#  '3.A.11': 5522,
#  'HTH_5': 5516,
#  '1.I.1': 5422,
#  '2.A.109': 5319,
#  'HTH_11': 5295,
#  'SBP_bac_3': 5278,
#  'GT35': 5276,
#  'CheW': 5233,
#  '9.B.97': 5218,
#  'PALP': 5101,
#  '3.A.9': 5101,
#  'HTH_6': 5099,
#  '2.A.63': 5005,
#  'GH31': 4788,
#  '2.A.53': 4758,
#  'Sigma70_r4': 4729,
#  '2.A.80': 4707,
#  'AA3_2': 4686,
#  'GT83': 4660,
#  '3.D.10': 4584,
#  '2.A.86': 4573,
#  'CbiA': 4551,
#  'GT1': 4526,
#  '9.B.146': 4499,
#  '1.B.18': 4443,
#  'CBS': 4382,
#  '2.A.76': 4346,
#  'CE9': 4278,
#  'HD': 4276,
#  'Rhodanese': 4267,
#  '2.A.8': 4233,
#  '1.B.1': 4218,
#  'Pribosyltran': 4201,
#  'Fer4': 4133,
#  'GH13_11': 4127,
#  '9.A.40': 4120,
#  'GH20': 4085,
#  '1.B.42': 4079,
#  'CBM13': 4076,
#  '8.A.46': 4073,
#  '2.A.36': 4062,
#  'GH13_9': 4049,
#  'IclR': 4018,
#  'dCache_1': 4017,
#  'GT5': 4015,
#  '3.B.1': 3970,
#  'cNMP_binding': 3943,
#  'GH77': 3911,
#  '9.B.27': 3864,
#  'AAA': 3852,
#  '9.B.106': 3846,
#  '2.A.37': 3844,
#  'TPR_2': 3804,
#  '2.A.42': 3764,
#  'GAF': 3721,
#  '2.A.4': 3714,
#  'LytTR': 3624,
#  'GT20': 3619,
#  'TPR_1': 3568,
#  'GH36': 3556,
#  '9.B.33': 3540,
#  '1.B.6': 3495,
#  'GH92': 3475,
#  '9.A.8': 3419,
#  'GH13_31': 3414,
#  '2.A.38': 3382,
#  'AsnC_trans_reg': 3364,
#  'GT26': 3338,
#  '2.A.102': 3325,
#  'CE1': 3319,
#  'GT28': 3316,
#  '2.A.103': 3289,
#  '2.A.15': 3265,
#  'CSD': 3220,
#  'GH103': 3193,
#  'Peripla_BP_2': 3192,
#  '9.B.14': 3177,
#  'MCPsignal': 3139,
#  '2.A.115': 3124,
#  '1.B.12': 3114,
#  '9.B.126': 3108,
#  'GH105': 3102,
#  '1.B.11': 3086,
#  'GH25': 3054,
#  'GH65': 3019,
#  'GH8': 3015,
#  '3.D.5': 2997,
#  '3.D.6': 2993,
#  '2.A.108': 2966,
#  'GT8': 2959,
#  'GH38': 2942,
#  'ACT': 2934,
#  '1.B.17': 2934,
#  'GH0': 2931,
#  '3.D.2': 2929,
#  'GH29': 2924,
#  'Nitroreductase': 2858,
#  '9.B.102': 2837,
#  '1.B.33': 2794,
#  '2.A.47': 2785,
#  '1.B.55': 2774,
#  'GT30': 2758,
#  'CBM2': 2758,
#  'GH15': 2751,
#  '4.A.7': 2749,
#  '9.B.10': 2707,
#  '2.A.122': 2692,
#  'FecR': 2688,
#  '5.A.1': 2637,
#  '3.A.18': 2620,
#  '1.A.1': 2604,
#  'GH42': 2601,
#  '1.A.33': 2598,
#  'GH28': 2593,
#  '9.B.20': 2588,
#  '2.A.39': 2569,
#  '3.A.16': 2559,
#  '1.E.14': 2515,
#  '2.A.49': 2513,
#  '1.A.35': 2512,
#  '2.A.25': 2440,
#  'CBM6': 2436,
#  '1.B.22': 2429,
#  '8.A.7': 2384,
#  '4.F.1': 2374,
#  'Pyr_redox': 2373,
#  '9.B.158': 2342,
#  'GH51': 2328,
#  '1.A.8': 2321,
#  'GH78': 2312,
#  'CheR': 2306,
#  '2.A.16': 2285,
#  'GH37': 2283,
#  '4.D.3': 2280,
#  '2.A.14': 2262,
#  'CheB_methylest': 2260,
#  'HhH-GPD': 2259,
#  'AA10': 2252,
#  '2.A.88': 2244,
#  'GH33': 2243,
#  '1.B.3': 2231,
#  '2.A.17': 2213,
#  'PadR': 2211,
#  'Mga': 2179,
#  '9.B.44': 2165,
#  '9.A.11': 2162,
#  'H-kinase_dim': 2158,
#  'Sigma70_r3': 2151,
#  '2.A.13': 2151,
#  '2.A.55': 2150,
#  '1.A.11': 2143,
#  'HxlR': 2142,
#  '2.A.41': 2141,
#  '2.A.20': 2121,
#  'CheR_N': 2115,
#  '9.B.186': 2090,
#  'CBM5': 2074,
#  'GH127': 2043,
#  '1.A.34': 2022,
#  '2.A.64': 2020,
#  '9.B.174': 2010,
#  'CE14': 2004,
#  'SpoIIE': 2001,
#  '2.A.114': 1997,
#  'GH13_19': 1981,
#  'GH16_3': 1950,
#  'GH13_10': 1934,
#  '9.B.160': 1929,
#  '2.A.98': 1912,
#  'GH10': 1907,
#  '2.A.85': 1893,
#  'CE11': 1883,
#  '1.A.26': 1883,
#  'HTH_8': 1871,
#  '8.A.21': 1855,
#  '9.B.169': 1853,
#  '9.B.104': 1837,
#  '2.A.35': 1826,
#  '3.D.7': 1814,
#  'GH94': 1802,
#  'FlhC': 1792,
#  '4.A.5': 1791,
#  'CBM67': 1789,
#  'Peptidase_M23': 1784,
#  'FlhD': 1780,
#  'CBM35': 1779,
#  '2.A.19': 1777,
#  '1.E.43': 1759,
#  'GH13_3': 1755,
#  '9.B.35': 1751,
#  '9.A.25': 1739,
#  '2.C.1': 1735,
#  'Y_Y_Y': 1732,
#  '2.A.95': 1728,
#  'GH13': 1724,
#  'Glucokinase': 1708,
#  '2.A.50': 1707,
#  'GH35': 1706,
#  '2.A.69': 1701,
#  '1.A.16': 1699,
#  'GH13_16': 1695,
#  '2.A.28': 1692,
#  'Rrf2': 1682,
#  'CE12': 1678,
#  'CheY-binding': 1670,
#  'GT19': 1667,
#  'NIR_SIR': 1648,
#  '9.B.157': 1643,
#  'NIR_SIR_ferr': 1635,
#  'PIG-L': 1619,
#  'GH88': 1616,
#  'GH13_26': 1614,
#  'GH39': 1605,
#  'CheZ': 1592,
#  'GH19': 1590,
#  'HMA': 1577,
#  'GH95': 1575,
#  'GT25': 1569,
#  'GH130': 1568,
#  '2.A.78': 1563,
#  '1.E.53': 1534,
#  'GH63': 1516,
#  '3.A.24': 1512,
#  '3.A.25': 1509,
#  '9.B.74': 1504,
#  '2.A.22': 1502,
#  'GH13_29': 1497,
#  '9.B.121': 1483,
#  'CE8': 1471,
#  '2.A.45': 1466,
#  '9.B.22': 1463,
#  '1.A.22': 1456,
#  'GT107': 1454,
#  '1.C.113': 1446,
#  'GH13_20': 1433,
#  'STAS': 1429,
#  'SKI': 1428,
#  '4.A.4': 1424,
#  'GH13_18': 1418,
#  '1.A.62': 1406,
#  'Reg_prop': 1403,
#  '9.B.62': 1393,
#  '9.B.105': 1386,
#  'Pkinase': 1375,
#  'GyrI-like': 1371,
#  'GH102': 1368,
#  'GH97': 1359,
#  'GH24': 1353,
#  '3.D.9': 1346,
#  'GH13_30': 1337,
#  'GT41': 1336,
#  '2.A.79': 1308,
#  '9.B.124': 1302,
#  '3.D.3': 1301,
#  'GH9': 1301,
#  '1.A.14': 1298,
#  'Crp': 1294,
#  '1.A.43': 1284,
#  '2.A.113': 1271,
#  '8.A.8': 1264,
#  'GH13_5': 1229,
#  'FUR': 1227,
#  'FHA': 1224,
#  'GT32': 1222,
#  'GH43_26': 1220,
#  '9.B.114': 1218,
#  'FeoA': 1200,
#  'GH26': 1196,
#  '9.B.32': 1194,
#  'CBM41': 1187,
#  'CBM34': 1182,
#  '2.A.26': 1177,
#  'GH125': 1172,
#  'GH53': 1171,
#  '1.B.25': 1168,
#  'CE7': 1167,
#  'GH154': 1143,
#  'B12-binding': 1129,
#  'EPSP_synthase': 1112,
#  '3.A.12': 1103,
#  'GT81': 1102,
#  '5.B.3': 1100,
#  'PL22': 1094,
#  'GH13_23': 1088,
#  'Fe_dep_repress': 1086,
#  'Autoind_bind': 1082,
#  '1.B.20': 1081,
#  '4.B.1': 1080,
#  'ANTAR': 1069,
#  '2.A.81': 1067,
#  '2.A.58': 1054,
#  '2.A.33': 1048,
#  '9.B.143': 1043,
#  '9.B.1': 1041,
#  '2.A.9': 1040,
#  '9.B.99': 1035,
#  'GATase_2': 1030,
#  'PTS-HPr': 1009,
#  'Citrate_synt': 1006,
#  '2.A.51': 1003,
#  '1.B.76': 1001,
#  '9.B.142': 999,
#  '9.B.29': 998,
#  '9.B.149': 993,
#  'SBP_bac_5': 989,
#  '1.C.75': 987,
#  '2.A.27': 986,
#  '9.A.41': 978,
#  'CBM51': 966,
#  'GH57': 957,
#  'CE5': 952,
#  'GH43_11': 950,
#  'MASE1': 948,
#  'TetR_C': 946,
#  '9.B.28': 942,
#  'GH27': 942,
#  'GH153': 936,
#  '3.A.4': 935,
#  'GT87': 931,
#  '1.B.40': 931,
#  '2.A.5': 931,
#  '8.A.28': 930,
#  '2.A.89': 929,
#  '1.A.46': 929,
#  '1.A.104': 925,
#  'GH13_14': 918,
#  '1.A.12': 909,
#  '9.B.100': 903,
#  'GH6': 903,
#  '2.A.59': 901,
#  'CBM73': 886,
#  'GH13_13': 886,
#  '2.A.117': 882,
#  '9.B.67': 874,
#  '9.A.47': 868,
#  '9.B.43': 866,
#  '1.A.77': 864,
#  'Fe_dep_repr_C': 859,
#  '9.B.120': 857,
#  '1.B.9': 856,
#  'Hemerythrin': 856,
#  '9.B.136': 854,
#  'GH43_12': 849,
#  'HTH_7': 844,
#  'PspC': 843,
#  'AA2': 840,
#  'GH106': 836,
#  '2.A.11': 832,
#  'GH43_10': 830,
#  'BTAD': 817,
#  'NTP_transf_2': 815,
#  '2.A.118': 811,
#  'CBM66': 791,
#  'GH146': 788,
#  '2.A.72': 778,
#  'TOBE': 771,
#  '1.A.13': 764,
#  '1.B.35': 761,
#  'GT39': 761,
#  '5.A.2': 752,
#  '2.A.34': 746,
#  'CBM3': 745,
#  '2.A.121': 742,
#  'GT84': 728,
#  '1.C.82': 726,
#  'GH144': 721,
#  '8.A.4': 721,
#  'GH74': 719,
#  '2.A.107': 717,
#  'TrmB': 715,
#  '9.B.8': 714,
#  '2.A.61': 713,
#  '9.B.156': 713,
#  'CBM4': 710,
#  '2.A.123': 710,
#  '9.B.153': 707,
#  'CBM9': 706,
#  'GH76': 695,
#  '9.B.141': 692,
#  '9.B.31': 692,
#  'CBM12': 688,
#  '9.B.36': 682,
#  'PL1_2': 672,
#  '3.E.2': 670,
#  '2.A.46': 664,
#  'GT111': 660,
#  'AA6': 656,
#  'GH109': 653,
#  'GH68': 641,
#  'GT14': 638,
#  '5.B.1': 637,
#  '9.B.2': 633,
#  'GH141': 629,
#  '8.A.43': 628,
#  'PL11': 627,
#  '9.A.5': 624,
#  'CBM57': 624,
#  '2.A.24': 621,
#  '1.B.39': 619,
#  'GT104': 617,
#  '1.B.73': 609,
#  '1.C.80': 608,
#  '1.B.48': 604,
#  'Glycos_trans_3N': 601,
#  '1.E.34': 596,
#  '2.A.75': 596,
#  'AlkA_N': 592,
#  'GH87': 583,
#  'CBM20': 581,
#  'HEM4': 581,
#  'GT53': 580,
#  'GH108': 571,
#  '9.B.125': 571,
#  'GH115': 569,
#  'GH67': 561,
#  'GH55': 559,
#  '1.B.10': 557,
#  '1.B.23': 556,
#  '1.B.46': 553,
#  'GH43_34': 553,
#  'GT21': 552,
#  'dCache_2': 550,
#  '9.B.51': 547,
#  '2.A.68': 546,
#  'GH84': 546,
#  'PL0': 546,
#  '1.C.109': 544,
#  'CBM22': 542,
#  '9.B.42': 534,
#  '1.A.72': 526,
#  'CBM47': 526,
#  '4.D.1': 525,
#  'CBM38': 525,
#  '1.B.15': 525,
#  '1.E.40': 524,
#  '2.A.10': 524,
#  'GH30_3': 520,
#  'Penicillinase_R': 518,
#  'GH43_24': 517,
#  '2.A.120': 516,
#  '2.A.52': 514,
#  '1.B.54': 511,
#  '4.D.2': 510,
#  'GH43_4': 510,
#  'Ada_Zn_binding': 498,
#  'Guanylate_cyc': 496,
#  '9.B.72': 484,
#  '9.A.4': 482,
#  'GH43_29': 482,
#  'GH133': 481,
#  'CBM16': 481,
#  'GH5_2': 480,
#  '1.B.19': 478,
#  '2.A.119': 476,
#  'GT76': 476,
#  '5.B.7': 475,
#  '1.B.4': 473,
#  'GH114': 471,
#  '1.B.21': 470,
#  'SpoVT_AbrB': 466,
#  '9.B.55': 466,
#  'Whib': 465,
#  'GH85': 462,
#  'GH13_21': 455,
#  '2.A.106': 455,
#  'GH5': 454,
#  'ATPase_2': 451,
#  '1.B.70': 450,
#  '2.A.87': 446,
#  'CBM61': 441,
#  'GH136': 441,
#  'TrkA_C': 439,
#  'PL1_6': 439,
#  'GH43_5': 437,
#  '5.B.5': 435,
#  'CBM42': 426,
#  '9.B.65': 421,
#  '2.A.96': 421,
#  '2.A.67': 419,
#  'GH16_21': 418,
#  '9.B.144': 414,
#  'GH166': 411,
#  '9.B.4': 411,
#  'Trp_repressor': 409,
#  'GH17': 405,
#  'DctP': 404,
#  'GT56': 403,
#  'GT11': 403,
#  'CE0': 401,
#  '9.B.211': 398,
#  'PL8': 398,
#  '9.B.176': 398,
#  'CE2': 398,
#  'GH16': 395,
#  'PL38': 394,
#  'B12-binding_2': 389,
#  '1.C.105': 385,
#  'GH140': 383,
#  'GH13_32': 381,
#  'GH117': 381,
#  '3.A.10': 380,
#  '1.C.57': 380,
#  'GH43_22': 380,
#  'AA3': 377,
#  'Arg_repressor': 377,
#  '8.B.24': 376,
#  '1.A.78': 376,
#  'GH13_36': 372,
#  'GH13_4': 371,
#  'PL1': 369,
#  'GT73': 368,
#  '9.B.145': 367,
#  'GH113': 365,
#  'CBM26': 363,
#  'GH89': 360,
#  '2.A.73': 360,
#  'GH5_13': 358,
#  'Diacid_rec': 357,
#  'GH104': 357,
#  'GH43_1': 356,
#  '9.B.159': 356,
#  'GH50': 353,
#  '1.E.1': 351,
#  'GH13_38': 346,
#  'GH5_8': 342,
#  'GH64': 342,
#  '1.C.36': 341,
#  'GH13_2': 341,
#  'CE6': 341,
#  'GH5_1': 339,
#  'GH5_5': 339,
#  '9.A.24': 339,
#  '9.B.183': 337,
#  'GT94': 333,
#  'GH12': 333,
#  '2.A.124': 330,
#  '1.C.39': 329,
#  '9.A.61': 329,
#  'GH129': 328,
#  'GH46': 328,
#  '9.B.128': 325,
#  'GT89': 323,
#  'PL9_1': 321,
#  'PL9': 321,
#  '9.B.15': 320,
#  '9.B.21': 320,
#  'LexA_DNA_bind': 318,
#  '1.M.1': 317,
#  'FMN_bind_2': 316,
#  'GH13_39': 315,
#  '9.B.110': 313,
#  'GH11': 313,
#  '3.A.8': 312,
#  '2.A.70': 311,
#  '9.B.116': 310,
#  'GH123': 308,
#  'PL12': 307,
#  'MHYT': 305,
#  'GH5_4': 303,
#  '9.B.12': 301,
#  'GH5_41': 301,
#  'PL9_2': 297,
#  'GT27': 294,
#  'PL26': 294,
#  'PL7_1': 290,
#  '9.B.172': 290,
#  'CBM25': 288,
#  'PL17': 283,
#  'HTH_10': 281,
#  '9.B.150': 280,
#  'PL12_3': 279,
#  'CE15': 279,
#  '1.B.13': 277,
#  '3.A.14': 277,
#  'GH30_8': 277,
#  'FmdA_AmdA': 276,
#  'GH30_1': 276,
#  '5.B.4': 276,
#  '1.B.5': 274,
#  '2.A.116': 274,
#  'PL6': 274,
#  'PL17_2': 274,
#  'GH43_16': 273,
#  'GH99': 271,
#  'CHASE3': 271,
#  'CBM69': 268,
#  'CYTH': 267,
#  'GT101': 267,
#  'GH43_18': 264,
#  '9.B.50': 262,
#  '9.A.18': 262,
#  '2.A.77': 260,
#  'GH158': 255,
#  'GH135': 254,
#  'peroxidase': 253,
#  '8.A.51': 252,
#  '1.E.19': 252,
#  'HTH_AraC': 251,
#  'GH43_9': 250,
#  'GH126': 250,
#  'GT52': 249,
#  'PL10_1': 248,
#  '1.B.71': 246,
#  '1.C.106': 243,
#  'CE16': 243,
#  'GH70': 243,
#  'BLUF': 242,
#  '2.A.62': 242,
#  'Cyanate_lyase': 241,
#  'GH5_18': 240,
#  'GH62': 238,
#  '9.B.111': 237,
#  'GH116': 237,
#  '1.B.66': 236,
#  '1.B.77': 235,
#  'GH101': 233,
#  'GH48': 233,
#  'CE3': 232,
#  'GH91': 230,
#  '1.E.2': 227,
#  'HTH_Mga': 227,
#  'GH112': 227,
#  'GT66': 227,
#  'SLH': 225,
#  'GT85': 225,
#  'PL33_1': 223,
#  'GH13_33': 222,
#  '8.A.2': 221,
#  'FIST': 220,
#  'GT108': 219,
#  '1.A.4': 217,
#  'PL6_1': 217,
#  'GH30_5': 214,
#  '1.B.44': 213,
#  'GH43_3': 212,
#  'AA7': 210,
#  'GH13_27': 209,
#  'CBM44': 209,
#  'GH81': 209,
#  'GH5_7': 207,
#  'GH16_5': 206,
#  'GH13_28': 206,
#  'GT60': 205,
#  'GH5_25': 205,
#  'PL7_5': 205,
#  'CBM54': 205,
#  'GH43_28': 204,
#  '9.B.115': 202,
#  '3.A.20': 202,
#  'SBP_bac_10': 202,
#  'GH145': 201,
#  '2.A.83': 198,
#  '2.A.111': 198,
#  'Arc': 198,
#  '3.A.17': 198,
#  'CheC': 198,
#  '1.A.45': 197,
#  'GH110': 197,
#  'Nitro_FeMo-Co': 196,
#  'CBM63': 193,
#  '9.B.164': 190,
#  '1.C.1': 189,
#  'TPR_4': 189,
#  'PSK_trans_fac': 186,
#  '1.A.29': 186,
#  '3.E.1': 183,
#  'PglZ': 183,
#  'PL5_1': 182,
#  'GT10': 181,
#  '9.A.21': 180,
#  '1.E.31': 179,
#  'PL1_5': 177,
#  '8.A.48': 177,
#  'TPR_3': 174,
#  'PHY': 172,
#  '1.B.57': 172,
#  'GH30_2': 172,
#  'GH30_4': 172,
#  '9.B.69': 170,
#  'CBM46': 169,
#  '9.B.96': 168,
#  'GH93': 168,
#  'GH148': 167,
#  '2.A.104': 166,
#  '1.A.25': 166,
#  'NIT': 166,
#  '1.C.107': 166,
#  'CBM56': 165,
#  '9.B.209': 165,
#  'AA5': 164,
#  'GH5_46': 164,
#  'PL8_2': 163,
#  '9.B.140': 162,
#  '1.A.54': 162,
#  'PL11_1': 162,
#  'GH120': 161,
#  'GH43_19': 161,
#  'GT44': 160,
#  'ArsD': 160,
#  'GH163': 159,
#  'PL12_1': 158,
#  'GH43_17': 157,
#  'GH142': 155,
#  'PL3_1': 154,
#  '8.A.79': 152,
#  'SirB': 152,
#  '1.E.11': 151,
#  'GH66': 151,
#  '9.B.52': 150,
#  'GH13_8': 150,
#  '9.B.46': 148,
#  'GH100': 148,
#  'CHASE4': 147,
#  'PL8_3': 147,
#  '4.C.3': 146,
#  'GT3': 145,
#  'CHASE': 145,
#  'GH13_12': 143,
#  'PL1_8': 143,
#  'GH43_2': 143,
#  'PL29': 143,
#  '9.B.196': 141,
#  '9.B.179': 141,
#  'cohesin': 139,
#  'GH59': 139,
#  'PL2_1': 138,
#  'GH165': 138,
#  'GH5_44': 138,
#  'HTH_12': 138,
#  '8.A.35': 137,
#  'GH151': 136,
#  'GH13_1': 136,
#  'HEAT_PBS': 135,
#  '1.C.98': 135,
#  'bZIP_1': 135,
#  'GH128': 135,
#  'RseA_N': 134,
#  'GH79': 134,
#  'PL7': 134,
#  '1.B.27': 133,
#  '1.E.56': 132,
#  '1.E.54': 132,
#  '9.A.55': 131,
#  'PL3_4': 131,
#  'GH54': 131,
#  '9.B.127': 131,
#  'CBM40': 130,
#  'CBM71': 129,
#  '1.B.26': 128,
#  'HTH_psq': 128,
#  'PL5': 128,
#  '9.B.98': 127,
#  'CBM23': 126,
#  'Sigma70_ECF': 126,
#  '1.A.87': 125,
#  'GH43': 125,
#  'GH43_31': 125,
#  '1.C.12': 124,
#  'GT17': 124,
#  '2.A.12': 123,
#  'AA4': 123,
#  '1.C.10': 122,
#  'PL31': 122,
#  '1.C.72': 121,
#  'GH43_30': 121,
#  'Fez1': 120,
#  'GH43_32': 120,
#  'PL33_2': 119,
#  'GH13_42': 118,
#  'CBM68': 117,
#  'GT102': 116,
#  '2.A.99': 116,
#  '9.A.28': 115,
#  '9.A.39': 115,
#  '9.B.85': 114,
#  'SfsA': 113,
#  'CtsR': 113,
#  'GH137': 113,
#  '1.B.16': 112,
#  'GH86': 112,
#  '1.C.41': 112,
#  'PL35': 112,
#  '1.B.81': 111,
#  'CHASE2': 111,
#  '9.A.15': 110,
#  'GH75': 110,
#  'PL8_1': 109,
#  'GH5_39': 109,
#  'GH138': 109,
#  '1.B.68': 108,
#  'GH13_37': 107,
#  '1.E.55': 106,
#  'HHA': 106,
#  'GH159': 106,
#  '9.B.155': 105,
#  '1.A.6': 105,
#  'GH16_9': 105,
#  'GH149': 105,
#  '9.B.148': 105,
#  '1.B.75': 105,
#  'GH52': 104,
#  '9.B.24': 103,
#  'CBM62': 103,
#  '9.A.23': 102,
#  'CheD': 102,
#  'GH43_23': 102,
#  'GH121': 101,
#  'PL40': 101,
#  '2.A.101': 100,
#  '9.B.13': 99,
#  'GT70': 98,
#  '1.E.26': 98,
#  '1.E.22': 98,
#  'GH44': 98,
#  'GH139': 98,
#  'PL16': 97,
#  'CsrA': 97,
#  'GH5_28': 97,
#  '1.A.2': 97,
#  '1.B.50': 96,
#  'PL1_3': 96,
#  '1.A.63': 96,
#  'GH5_48': 95,
#  '1.A.28': 95,
#  'GH13_41': 95,
#  '1.A.10': 94,
#  'ROS_MUCR': 92,
#  'GH43_8': 92,
#  'GT42': 91,
#  'GH5_19': 90,
#  'HNOB': 90,
#  '9.B.75': 89,
#  '1.E.52': 89,
#  'GH43_27': 88,
#  'GH16_7': 88,
#  '9.B.70': 88,
#  'PL22_2': 88,
#  'Phage_AlpA': 88,
#  'PL2_2': 86,
#  '1.B.62': 86,
#  '9.B.73': 86,
#  'GH5_35': 86,
#  'GH161': 85,
#  'CBM27': 85,
#  'GH147': 85,
#  'PL9_3': 84,
#  '9.B.168': 84,
#  'PL22_1': 84,
#  'GT23': 83,
#  'AA5_2': 83,
#  'GH13_7': 83,
#  'PL7_3': 82,
#  'GH43_35': 82,
#  'GH98': 81,
#  'GH30': 81,
#  '1.E.5': 79,
#  '9.B.30': 79,
#  '1.K.4': 79,
#  '9.B.185': 79,
#  'GH143': 79,
#  'GH14': 79,
#  'CBM36': 79,
#  'MetJ': 78,
#  '1.C.65': 76,
#  'CBM11': 76,
#  '9.B.107': 76,
#  'GT82': 75,
#  '9.B.118': 75,
#  'YcbB': 75,
#  '9.A.10': 74,
#  '1.A.105': 74,
#  'PL6_2': 74,
#  '9.B.182': 73,
#  '1.A.17': 73,
#  '1.E.27': 72,
#  '1.B.79': 72,
#  'GH5_40': 72,
#  'GH13_6': 72,
#  '9.B.117': 71,
#  'GT92': 71,
#  '1.C.67': 71,
#  '9.A.31': 69,
#  'CBM70': 68,
#  'PL4_1': 68,
#  'GH16_24': 68,
#  '9.B.76': 67,
#  'GT45': 66,
#  '2.A.71': 66,
#  '3.D.8': 65,
#  '1.C.14': 64,
#  'HTH_CodY': 64,
#  '9.B.171': 64,
#  '9.A.36': 63,
#  'PL17_1': 62,
#  'GT100': 62,
#  '1.E.23': 61,
#  'FeS': 60,
#  'GH5_51': 60,
#  '1.E.20': 59,
#  'GH16_16': 59,
#  '8.A.58': 59,
#  '1.C.11': 58,
#  'GH43_33': 58,
#  'Ogr_Delta': 57,
#  'GT22': 55,
#  'GcrA': 55,
#  'GH71': 55,
#  '1.C.3': 54,
#  '1.E.29': 54,
#  'PL4_4': 54,
#  'GH43_37': 54,
#  'CBM59': 54,
#  '1.E.24': 53,
#  'PL10_2': 53,
#  'PL14_3': 53,
#  ...}

# %%
import gensim

# %%
gene_list_tagged = [gensim.models.doc2vec.TaggedDocument(seq_list, [i]) for i, seq_list in enumerate(gene_list)]

# %%
gene_list_tagged[:5]
# Out:
# [TaggedDocument(words=['1.A.72', 'MerR', 'GH23'], tags=[0]),
#  TaggedDocument(words=['3.A.1', 'CE4'], tags=[1]),
#  TaggedDocument(words=['3.A.23', '9.A.5', 'MCPsignal', '2.A.21', '2.A.22', 'TetR_N', '3.A.1', '3.A.1', 'HATPase_c', 'HisKA', '1.A.8', '2.A.25', '2.A.66', '4.A.1', 'GH13_29', 'GntR', '3.A.1', 'GGDEF', 'PAS', 'DeoRC', 'HTH_DeoR', 'PfkB', '4.A.2', '2.A.88'], tags=[2]),
#  TaggedDocument(words=['CE4', '8.A.5', '3.A.1', '3.A.1', '3.A.1'], tags=[3]),
#  TaggedDocument(words=['GT51', 'Peripla_BP_2', '3.A.1', '3.A.1', '9.B.169'], tags=[4])]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer(tokenizer=lambda x: str(x).split(','), lowercase = False, min_df = 5)

# %%
gene_seq = [seq.replace("|", ",") for seq in updated_data_supervised["sequence"]]

# %%
vectorizer.fit(gene_seq)
# Out:
# C:\Users\vedpi\anaconda3\envs\newone\lib\site-packages\sklearn\feature_extraction\text.py:516: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# CountVectorizer(lowercase=False, min_df=5,
#                 tokenizer=<function <lambda> at 0x00000200ED126820>)

# %%
np.sum(vectorizer.fit_transform(gene_seq).toarray().sum(axis = 1) == 0)
# Out:
# 0

# %%
len(vectorizer.vocabulary_)/len(np.unique([gene for seq in gene_list for gene in seq]))
# Out:
# 0.9077912794853467

# %%
reduced_freq_count = {k:D[k] for k,v in vectorizer.vocabulary_.items()}

# %%
# sort in descending order
D_reduced =dict(sorted(reduced_freq_count.items(), key=lambda item: item[1], reverse = True))

# manipulate for plotting
first2pairs = {k: D_reduced[k] for k in list(D_reduced)}

# variable assignment
D_reduced = first2pairs

# %%
D_reduced
# Out:
# {'3.A.1': 445283,
#  '2.A.1': 86993,
#  'GT2': 63177,
#  'GT4': 51694,
#  'Response_reg': 47633,
#  'HTH_1': 35098,
#  'LysR_substrate': 34217,
#  'HATPase_c': 32140,
#  '1.B.14': 30074,
#  '2.A.6': 30034,
#  'HTH_18': 30022,
#  'LacI': 27823,
#  'Peripla_BP_3': 26545,
#  '3.D.1': 23750,
#  'GntR': 21481,
#  '3.A.23': 21451,
#  'HisKA': 21220,
#  '2.A.7': 21112,
#  'TetR_N': 19234,
#  '9.B.34': 18879,
#  'Aminotran_1_2': 18840,
#  '4.C.1': 17277,
#  '2.A.3': 17144,
#  '2.A.21': 16753,
#  'Trans_reg_C': 15767,
#  '1.B.52': 15574,
#  'GerE': 15035,
#  '4.A.3': 14725,
#  '9.B.18': 14724,
#  '4.A.1': 14310,
#  'GH23': 14259,
#  '3.A.6': 13979,
#  'PfkB': 13797,
#  'Pyr_redox_2': 13724,
#  '5.A.3': 13497,
#  '3.A.7': 13481,
#  'GH1': 13152,
#  '3.A.3': 12936,
#  'MarR': 12691,
#  'SBP_bac_1': 12648,
#  'GH3': 12597,
#  'AraC_binding': 12568,
#  '3.A.2': 12448,
#  '2.A.66': 12110,
#  '4.A.2': 11490,
#  '8.A.5': 11374,
#  'GT51': 11271,
#  'SIS': 11196,
#  '3.D.4': 11105,
#  'HTH_3': 10880,
#  '1.A.30': 10515,
#  '4.A.6': 10296,
#  'Sigma70_r2': 10134,
#  'GH2': 9472,
#  'CE4': 9317,
#  '2.A.56': 9090,
#  '3.A.15': 8573,
#  '8.A.3': 8415,
#  '2.A.2': 8384,
#  'PAS': 8255,
#  'CBM50': 8116,
#  'GT9': 8037,
#  'EAL': 7800,
#  'GT0': 7701,
#  'Sigma70_r4_2': 7661,
#  'NUDIX': 7491,
#  '3.A.5': 7415,
#  'Peripla_BP_1': 7106,
#  '2.A.23': 6874,
#  '8.A.59': 6789,
#  'CBM48': 6743,
#  '2.A.40': 6404,
#  'HTH_DeoR': 6312,
#  'Glyoxalase': 6276,
#  'GH73': 6139,
#  'GH32': 6034,
#  '1.A.23': 5997,
#  '8.A.1': 5920,
#  'GGDEF': 5866,
#  'MerR': 5862,
#  'HTH_IclR': 5833,
#  'CBM32': 5759,
#  'GH18': 5754,
#  'DeoRC': 5657,
#  'GH4': 5621,
#  '3.A.11': 5522,
#  'HTH_5': 5516,
#  '1.I.1': 5422,
#  '2.A.109': 5319,
#  'HTH_11': 5295,
#  'SBP_bac_3': 5278,
#  'GT35': 5276,
#  'CheW': 5233,
#  '9.B.97': 5218,
#  'PALP': 5101,
#  '3.A.9': 5101,
#  'HTH_6': 5099,
#  '2.A.63': 5005,
#  'GH31': 4788,
#  '2.A.53': 4758,
#  'Sigma70_r4': 4729,
#  '2.A.80': 4707,
#  'AA3_2': 4686,
#  'GT83': 4660,
#  '3.D.10': 4584,
#  '2.A.86': 4573,
#  'CbiA': 4551,
#  'GT1': 4526,
#  '9.B.146': 4499,
#  '1.B.18': 4443,
#  'CBS': 4382,
#  '2.A.76': 4346,
#  'CE9': 4278,
#  'HD': 4276,
#  'Rhodanese': 4267,
#  '2.A.8': 4233,
#  '1.B.1': 4218,
#  'Pribosyltran': 4201,
#  'Fer4': 4133,
#  'GH13_11': 4127,
#  '9.A.40': 4120,
#  'GH20': 4085,
#  '1.B.42': 4079,
#  'CBM13': 4076,
#  '8.A.46': 4073,
#  '2.A.36': 4062,
#  'GH13_9': 4049,
#  'IclR': 4018,
#  'dCache_1': 4017,
#  'GT5': 4015,
#  '3.B.1': 3970,
#  'cNMP_binding': 3943,
#  'GH77': 3911,
#  '9.B.27': 3864,
#  'AAA': 3852,
#  '9.B.106': 3846,
#  '2.A.37': 3844,
#  'TPR_2': 3804,
#  '2.A.42': 3764,
#  'GAF': 3721,
#  '2.A.4': 3714,
#  'LytTR': 3624,
#  'GT20': 3619,
#  'TPR_1': 3568,
#  'GH36': 3556,
#  '9.B.33': 3540,
#  '1.B.6': 3495,
#  'GH92': 3475,
#  '9.A.8': 3419,
#  'GH13_31': 3414,
#  '2.A.38': 3382,
#  'AsnC_trans_reg': 3364,
#  'GT26': 3338,
#  '2.A.102': 3325,
#  'CE1': 3319,
#  'GT28': 3316,
#  '2.A.103': 3289,
#  '2.A.15': 3265,
#  'CSD': 3220,
#  'GH103': 3193,
#  'Peripla_BP_2': 3192,
#  '9.B.14': 3177,
#  'MCPsignal': 3139,
#  '2.A.115': 3124,
#  '1.B.12': 3114,
#  '9.B.126': 3108,
#  'GH105': 3102,
#  '1.B.11': 3086,
#  'GH25': 3054,
#  'GH65': 3019,
#  'GH8': 3015,
#  '3.D.5': 2997,
#  '3.D.6': 2993,
#  '2.A.108': 2966,
#  'GT8': 2959,
#  'GH38': 2942,
#  'ACT': 2934,
#  '1.B.17': 2934,
#  'GH0': 2931,
#  '3.D.2': 2929,
#  'GH29': 2924,
#  'Nitroreductase': 2858,
#  '9.B.102': 2837,
#  '1.B.33': 2794,
#  '2.A.47': 2785,
#  '1.B.55': 2774,
#  'GT30': 2758,
#  'CBM2': 2758,
#  'GH15': 2751,
#  '4.A.7': 2749,
#  '9.B.10': 2707,
#  '2.A.122': 2692,
#  'FecR': 2688,
#  '5.A.1': 2637,
#  '3.A.18': 2620,
#  '1.A.1': 2604,
#  'GH42': 2601,
#  '1.A.33': 2598,
#  'GH28': 2593,
#  '9.B.20': 2588,
#  '2.A.39': 2569,
#  '3.A.16': 2559,
#  '1.E.14': 2515,
#  '2.A.49': 2513,
#  '1.A.35': 2512,
#  '2.A.25': 2440,
#  'CBM6': 2436,
#  '1.B.22': 2429,
#  '8.A.7': 2384,
#  '4.F.1': 2374,
#  'Pyr_redox': 2373,
#  '9.B.158': 2342,
#  'GH51': 2328,
#  '1.A.8': 2321,
#  'GH78': 2312,
#  'CheR': 2306,
#  '2.A.16': 2285,
#  'GH37': 2283,
#  '4.D.3': 2280,
#  '2.A.14': 2262,
#  'CheB_methylest': 2260,
#  'HhH-GPD': 2259,
#  'AA10': 2252,
#  '2.A.88': 2244,
#  'GH33': 2243,
#  '1.B.3': 2231,
#  '2.A.17': 2213,
#  'PadR': 2211,
#  'Mga': 2179,
#  '9.B.44': 2165,
#  '9.A.11': 2162,
#  'H-kinase_dim': 2158,
#  'Sigma70_r3': 2151,
#  '2.A.13': 2151,
#  '2.A.55': 2150,
#  '1.A.11': 2143,
#  'HxlR': 2142,
#  '2.A.41': 2141,
#  '2.A.20': 2121,
#  'CheR_N': 2115,
#  '9.B.186': 2090,
#  'CBM5': 2074,
#  'GH127': 2043,
#  '1.A.34': 2022,
#  '2.A.64': 2020,
#  '9.B.174': 2010,
#  'CE14': 2004,
#  'SpoIIE': 2001,
#  '2.A.114': 1997,
#  'GH13_19': 1981,
#  'GH16_3': 1950,
#  'GH13_10': 1934,
#  '9.B.160': 1929,
#  '2.A.98': 1912,
#  'GH10': 1907,
#  '2.A.85': 1893,
#  'CE11': 1883,
#  '1.A.26': 1883,
#  'HTH_8': 1871,
#  '8.A.21': 1855,
#  '9.B.169': 1853,
#  '9.B.104': 1837,
#  '2.A.35': 1826,
#  '3.D.7': 1814,
#  'GH94': 1802,
#  'FlhC': 1792,
#  '4.A.5': 1791,
#  'CBM67': 1789,
#  'Peptidase_M23': 1784,
#  'FlhD': 1780,
#  'CBM35': 1779,
#  '2.A.19': 1777,
#  '1.E.43': 1759,
#  'GH13_3': 1755,
#  '9.B.35': 1751,
#  '9.A.25': 1739,
#  '2.C.1': 1735,
#  'Y_Y_Y': 1732,
#  '2.A.95': 1728,
#  'GH13': 1724,
#  'Glucokinase': 1708,
#  '2.A.50': 1707,
#  'GH35': 1706,
#  '2.A.69': 1701,
#  '1.A.16': 1699,
#  'GH13_16': 1695,
#  '2.A.28': 1692,
#  'Rrf2': 1682,
#  'CE12': 1678,
#  'CheY-binding': 1670,
#  'GT19': 1667,
#  'NIR_SIR': 1648,
#  '9.B.157': 1643,
#  'NIR_SIR_ferr': 1635,
#  'PIG-L': 1619,
#  'GH88': 1616,
#  'GH13_26': 1614,
#  'GH39': 1605,
#  'CheZ': 1592,
#  'GH19': 1590,
#  'HMA': 1577,
#  'GH95': 1575,
#  'GT25': 1569,
#  'GH130': 1568,
#  '2.A.78': 1563,
#  '1.E.53': 1534,
#  'GH63': 1516,
#  '3.A.24': 1512,
#  '3.A.25': 1509,
#  '9.B.74': 1504,
#  '2.A.22': 1502,
#  'GH13_29': 1497,
#  '9.B.121': 1483,
#  'CE8': 1471,
#  '2.A.45': 1466,
#  '9.B.22': 1463,
#  '1.A.22': 1456,
#  'GT107': 1454,
#  '1.C.113': 1446,
#  'GH13_20': 1433,
#  'STAS': 1429,
#  'SKI': 1428,
#  '4.A.4': 1424,
#  'GH13_18': 1418,
#  '1.A.62': 1406,
#  'Reg_prop': 1403,
#  '9.B.62': 1393,
#  '9.B.105': 1386,
#  'Pkinase': 1375,
#  'GyrI-like': 1371,
#  'GH102': 1368,
#  'GH97': 1359,
#  'GH24': 1353,
#  '3.D.9': 1346,
#  'GH13_30': 1337,
#  'GT41': 1336,
#  '2.A.79': 1308,
#  '9.B.124': 1302,
#  '3.D.3': 1301,
#  'GH9': 1301,
#  '1.A.14': 1298,
#  'Crp': 1294,
#  '1.A.43': 1284,
#  '2.A.113': 1271,
#  '8.A.8': 1264,
#  'GH13_5': 1229,
#  'FUR': 1227,
#  'FHA': 1224,
#  'GT32': 1222,
#  'GH43_26': 1220,
#  '9.B.114': 1218,
#  'FeoA': 1200,
#  'GH26': 1196,
#  '9.B.32': 1194,
#  'CBM41': 1187,
#  'CBM34': 1182,
#  '2.A.26': 1177,
#  'GH125': 1172,
#  'GH53': 1171,
#  '1.B.25': 1168,
#  'CE7': 1167,
#  'GH154': 1143,
#  'B12-binding': 1129,
#  'EPSP_synthase': 1112,
#  '3.A.12': 1103,
#  'GT81': 1102,
#  '5.B.3': 1100,
#  'PL22': 1094,
#  'GH13_23': 1088,
#  'Fe_dep_repress': 1086,
#  'Autoind_bind': 1082,
#  '1.B.20': 1081,
#  '4.B.1': 1080,
#  'ANTAR': 1069,
#  '2.A.81': 1067,
#  '2.A.58': 1054,
#  '2.A.33': 1048,
#  '9.B.143': 1043,
#  '9.B.1': 1041,
#  '2.A.9': 1040,
#  '9.B.99': 1035,
#  'GATase_2': 1030,
#  'PTS-HPr': 1009,
#  'Citrate_synt': 1006,
#  '2.A.51': 1003,
#  '1.B.76': 1001,
#  '9.B.142': 999,
#  '9.B.29': 998,
#  '9.B.149': 993,
#  'SBP_bac_5': 989,
#  '1.C.75': 987,
#  '2.A.27': 986,
#  '9.A.41': 978,
#  'CBM51': 966,
#  'GH57': 957,
#  'CE5': 952,
#  'GH43_11': 950,
#  'MASE1': 948,
#  'TetR_C': 946,
#  '9.B.28': 942,
#  'GH27': 942,
#  'GH153': 936,
#  '3.A.4': 935,
#  'GT87': 931,
#  '1.B.40': 931,
#  '2.A.5': 931,
#  '8.A.28': 930,
#  '2.A.89': 929,
#  '1.A.46': 929,
#  '1.A.104': 925,
#  'GH13_14': 918,
#  '1.A.12': 909,
#  '9.B.100': 903,
#  'GH6': 903,
#  '2.A.59': 901,
#  'CBM73': 886,
#  'GH13_13': 886,
#  '2.A.117': 882,
#  '9.B.67': 874,
#  '9.A.47': 868,
#  '9.B.43': 866,
#  '1.A.77': 864,
#  'Fe_dep_repr_C': 859,
#  '9.B.120': 857,
#  '1.B.9': 856,
#  'Hemerythrin': 856,
#  '9.B.136': 854,
#  'GH43_12': 849,
#  'HTH_7': 844,
#  'PspC': 843,
#  'AA2': 840,
#  'GH106': 836,
#  '2.A.11': 832,
#  'GH43_10': 830,
#  'BTAD': 817,
#  'NTP_transf_2': 815,
#  '2.A.118': 811,
#  'CBM66': 791,
#  'GH146': 788,
#  '2.A.72': 778,
#  'TOBE': 771,
#  '1.A.13': 764,
#  '1.B.35': 761,
#  'GT39': 761,
#  '5.A.2': 752,
#  '2.A.34': 746,
#  'CBM3': 745,
#  '2.A.121': 742,
#  'GT84': 728,
#  '1.C.82': 726,
#  'GH144': 721,
#  '8.A.4': 721,
#  'GH74': 719,
#  '2.A.107': 717,
#  'TrmB': 715,
#  '9.B.8': 714,
#  '2.A.61': 713,
#  '9.B.156': 713,
#  'CBM4': 710,
#  '2.A.123': 710,
#  '9.B.153': 707,
#  'CBM9': 706,
#  'GH76': 695,
#  '9.B.141': 692,
#  '9.B.31': 692,
#  'CBM12': 688,
#  '9.B.36': 682,
#  'PL1_2': 672,
#  '3.E.2': 670,
#  '2.A.46': 664,
#  'GT111': 660,
#  'AA6': 656,
#  'GH109': 653,
#  'GH68': 641,
#  'GT14': 638,
#  '5.B.1': 637,
#  '9.B.2': 633,
#  'GH141': 629,
#  '8.A.43': 628,
#  'PL11': 627,
#  '9.A.5': 624,
#  'CBM57': 624,
#  '2.A.24': 621,
#  '1.B.39': 619,
#  'GT104': 617,
#  '1.B.73': 609,
#  '1.C.80': 608,
#  '1.B.48': 604,
#  'Glycos_trans_3N': 601,
#  '1.E.34': 596,
#  '2.A.75': 596,
#  'AlkA_N': 592,
#  'GH87': 583,
#  'CBM20': 581,
#  'HEM4': 581,
#  'GT53': 580,
#  'GH108': 571,
#  '9.B.125': 571,
#  'GH115': 569,
#  'GH67': 561,
#  'GH55': 559,
#  '1.B.10': 557,
#  '1.B.23': 556,
#  '1.B.46': 553,
#  'GH43_34': 553,
#  'GT21': 552,
#  'dCache_2': 550,
#  '9.B.51': 547,
#  '2.A.68': 546,
#  'GH84': 546,
#  'PL0': 546,
#  '1.C.109': 544,
#  'CBM22': 542,
#  '9.B.42': 534,
#  '1.A.72': 526,
#  'CBM47': 526,
#  '4.D.1': 525,
#  'CBM38': 525,
#  '1.B.15': 525,
#  '1.E.40': 524,
#  '2.A.10': 524,
#  'GH30_3': 520,
#  'Penicillinase_R': 518,
#  'GH43_24': 517,
#  '2.A.120': 516,
#  '2.A.52': 514,
#  '1.B.54': 511,
#  '4.D.2': 510,
#  'GH43_4': 510,
#  'Ada_Zn_binding': 498,
#  'Guanylate_cyc': 496,
#  '9.B.72': 484,
#  '9.A.4': 482,
#  'GH43_29': 482,
#  'GH133': 481,
#  'CBM16': 481,
#  'GH5_2': 480,
#  '1.B.19': 478,
#  '2.A.119': 476,
#  'GT76': 476,
#  '5.B.7': 475,
#  '1.B.4': 473,
#  'GH114': 471,
#  '1.B.21': 470,
#  'SpoVT_AbrB': 466,
#  '9.B.55': 466,
#  'Whib': 465,
#  'GH85': 462,
#  'GH13_21': 455,
#  '2.A.106': 455,
#  'GH5': 454,
#  'ATPase_2': 451,
#  '1.B.70': 450,
#  '2.A.87': 446,
#  'CBM61': 441,
#  'GH136': 441,
#  'TrkA_C': 439,
#  'PL1_6': 439,
#  'GH43_5': 437,
#  '5.B.5': 435,
#  'CBM42': 426,
#  '9.B.65': 421,
#  '2.A.96': 421,
#  '2.A.67': 419,
#  'GH16_21': 418,
#  '9.B.144': 414,
#  'GH166': 411,
#  '9.B.4': 411,
#  'Trp_repressor': 409,
#  'GH17': 405,
#  'DctP': 404,
#  'GT56': 403,
#  'GT11': 403,
#  'CE0': 401,
#  '9.B.211': 398,
#  'PL8': 398,
#  '9.B.176': 398,
#  'CE2': 398,
#  'GH16': 395,
#  'PL38': 394,
#  'B12-binding_2': 389,
#  '1.C.105': 385,
#  'GH140': 383,
#  'GH13_32': 381,
#  'GH117': 381,
#  '3.A.10': 380,
#  '1.C.57': 380,
#  'GH43_22': 380,
#  'AA3': 377,
#  'Arg_repressor': 377,
#  '8.B.24': 376,
#  '1.A.78': 376,
#  'GH13_36': 372,
#  'GH13_4': 371,
#  'PL1': 369,
#  'GT73': 368,
#  '9.B.145': 367,
#  'GH113': 365,
#  'CBM26': 363,
#  'GH89': 360,
#  '2.A.73': 360,
#  'GH5_13': 358,
#  'Diacid_rec': 357,
#  'GH104': 357,
#  'GH43_1': 356,
#  '9.B.159': 356,
#  'GH50': 353,
#  '1.E.1': 351,
#  'GH13_38': 346,
#  'GH5_8': 342,
#  'GH64': 342,
#  '1.C.36': 341,
#  'GH13_2': 341,
#  'CE6': 341,
#  'GH5_1': 339,
#  'GH5_5': 339,
#  '9.A.24': 339,
#  '9.B.183': 337,
#  'GT94': 333,
#  'GH12': 333,
#  '2.A.124': 330,
#  '1.C.39': 329,
#  '9.A.61': 329,
#  'GH129': 328,
#  'GH46': 328,
#  '9.B.128': 325,
#  'GT89': 323,
#  'PL9_1': 321,
#  'PL9': 321,
#  '9.B.15': 320,
#  '9.B.21': 320,
#  'LexA_DNA_bind': 318,
#  '1.M.1': 317,
#  'FMN_bind_2': 316,
#  'GH13_39': 315,
#  '9.B.110': 313,
#  'GH11': 313,
#  '3.A.8': 312,
#  '2.A.70': 311,
#  '9.B.116': 310,
#  'GH123': 308,
#  'PL12': 307,
#  'MHYT': 305,
#  'GH5_4': 303,
#  '9.B.12': 301,
#  'GH5_41': 301,
#  'PL9_2': 297,
#  'GT27': 294,
#  'PL26': 294,
#  'PL7_1': 290,
#  '9.B.172': 290,
#  'CBM25': 288,
#  'PL17': 283,
#  'HTH_10': 281,
#  '9.B.150': 280,
#  'PL12_3': 279,
#  'CE15': 279,
#  '1.B.13': 277,
#  '3.A.14': 277,
#  'GH30_8': 277,
#  'FmdA_AmdA': 276,
#  'GH30_1': 276,
#  '5.B.4': 276,
#  '1.B.5': 274,
#  '2.A.116': 274,
#  'PL6': 274,
#  'PL17_2': 274,
#  'GH43_16': 273,
#  'GH99': 271,
#  'CHASE3': 271,
#  'CBM69': 268,
#  'CYTH': 267,
#  'GT101': 267,
#  'GH43_18': 264,
#  '9.B.50': 262,
#  '9.A.18': 262,
#  '2.A.77': 260,
#  'GH158': 255,
#  'GH135': 254,
#  'peroxidase': 253,
#  '8.A.51': 252,
#  '1.E.19': 252,
#  'HTH_AraC': 251,
#  'GH43_9': 250,
#  'GH126': 250,
#  'GT52': 249,
#  'PL10_1': 248,
#  '1.B.71': 246,
#  '1.C.106': 243,
#  'CE16': 243,
#  'GH70': 243,
#  'BLUF': 242,
#  '2.A.62': 242,
#  'Cyanate_lyase': 241,
#  'GH5_18': 240,
#  'GH62': 238,
#  '9.B.111': 237,
#  'GH116': 237,
#  '1.B.66': 236,
#  '1.B.77': 235,
#  'GH101': 233,
#  'GH48': 233,
#  'CE3': 232,
#  'GH91': 230,
#  '1.E.2': 227,
#  'HTH_Mga': 227,
#  'GH112': 227,
#  'GT66': 227,
#  'SLH': 225,
#  'GT85': 225,
#  'PL33_1': 223,
#  'GH13_33': 222,
#  '8.A.2': 221,
#  'FIST': 220,
#  'GT108': 219,
#  '1.A.4': 217,
#  'PL6_1': 217,
#  'GH30_5': 214,
#  '1.B.44': 213,
#  'GH43_3': 212,
#  'AA7': 210,
#  'GH13_27': 209,
#  'CBM44': 209,
#  'GH81': 209,
#  'GH5_7': 207,
#  'GH16_5': 206,
#  'GH13_28': 206,
#  'GT60': 205,
#  'GH5_25': 205,
#  'PL7_5': 205,
#  'CBM54': 205,
#  'GH43_28': 204,
#  '9.B.115': 202,
#  '3.A.20': 202,
#  'SBP_bac_10': 202,
#  'GH145': 201,
#  '2.A.83': 198,
#  '2.A.111': 198,
#  'Arc': 198,
#  '3.A.17': 198,
#  'CheC': 198,
#  '1.A.45': 197,
#  'GH110': 197,
#  'Nitro_FeMo-Co': 196,
#  'CBM63': 193,
#  '9.B.164': 190,
#  '1.C.1': 189,
#  'TPR_4': 189,
#  'PSK_trans_fac': 186,
#  '1.A.29': 186,
#  '3.E.1': 183,
#  'PglZ': 183,
#  'PL5_1': 182,
#  'GT10': 181,
#  '9.A.21': 180,
#  '1.E.31': 179,
#  'PL1_5': 177,
#  '8.A.48': 177,
#  'TPR_3': 174,
#  'PHY': 172,
#  '1.B.57': 172,
#  'GH30_2': 172,
#  'GH30_4': 172,
#  '9.B.69': 170,
#  'CBM46': 169,
#  '9.B.96': 168,
#  'GH93': 168,
#  'GH148': 167,
#  '2.A.104': 166,
#  '1.A.25': 166,
#  'NIT': 166,
#  '1.C.107': 166,
#  'CBM56': 165,
#  '9.B.209': 165,
#  'AA5': 164,
#  'GH5_46': 164,
#  'PL8_2': 163,
#  '9.B.140': 162,
#  '1.A.54': 162,
#  'PL11_1': 162,
#  'GH120': 161,
#  'GH43_19': 161,
#  'GT44': 160,
#  'ArsD': 160,
#  'GH163': 159,
#  'PL12_1': 158,
#  'GH43_17': 157,
#  'GH142': 155,
#  'PL3_1': 154,
#  '8.A.79': 152,
#  'SirB': 152,
#  '1.E.11': 151,
#  'GH66': 151,
#  '9.B.52': 150,
#  'GH13_8': 150,
#  '9.B.46': 148,
#  'GH100': 148,
#  'CHASE4': 147,
#  'PL8_3': 147,
#  '4.C.3': 146,
#  'GT3': 145,
#  'CHASE': 145,
#  'GH13_12': 143,
#  'PL1_8': 143,
#  'GH43_2': 143,
#  'PL29': 143,
#  '9.B.196': 141,
#  '9.B.179': 141,
#  'cohesin': 139,
#  'GH59': 139,
#  'PL2_1': 138,
#  'GH165': 138,
#  'GH5_44': 138,
#  'HTH_12': 138,
#  '8.A.35': 137,
#  'GH151': 136,
#  'GH13_1': 136,
#  'HEAT_PBS': 135,
#  '1.C.98': 135,
#  'bZIP_1': 135,
#  'GH128': 135,
#  'RseA_N': 134,
#  'GH79': 134,
#  'PL7': 134,
#  '1.B.27': 133,
#  '1.E.56': 132,
#  '1.E.54': 132,
#  '9.A.55': 131,
#  'PL3_4': 131,
#  'GH54': 131,
#  '9.B.127': 131,
#  'CBM40': 130,
#  'CBM71': 129,
#  '1.B.26': 128,
#  'HTH_psq': 128,
#  'PL5': 128,
#  '9.B.98': 127,
#  'CBM23': 126,
#  'Sigma70_ECF': 126,
#  '1.A.87': 125,
#  'GH43': 125,
#  'GH43_31': 125,
#  '1.C.12': 124,
#  'GT17': 124,
#  '2.A.12': 123,
#  'AA4': 123,
#  '1.C.10': 122,
#  'PL31': 122,
#  '1.C.72': 121,
#  'GH43_30': 121,
#  'Fez1': 120,
#  'GH43_32': 120,
#  'PL33_2': 119,
#  'GH13_42': 118,
#  'CBM68': 117,
#  'GT102': 116,
#  '2.A.99': 116,
#  '9.A.28': 115,
#  '9.A.39': 115,
#  '9.B.85': 114,
#  'SfsA': 113,
#  'CtsR': 113,
#  'GH137': 113,
#  '1.B.16': 112,
#  'GH86': 112,
#  '1.C.41': 112,
#  'PL35': 112,
#  '1.B.81': 111,
#  'CHASE2': 111,
#  '9.A.15': 110,
#  'GH75': 110,
#  'PL8_1': 109,
#  'GH5_39': 109,
#  'GH138': 109,
#  '1.B.68': 108,
#  'GH13_37': 107,
#  '1.E.55': 106,
#  'HHA': 106,
#  'GH159': 106,
#  '9.B.155': 105,
#  '1.A.6': 105,
#  'GH16_9': 105,
#  'GH149': 105,
#  '9.B.148': 105,
#  '1.B.75': 105,
#  'GH52': 104,
#  '9.B.24': 103,
#  'CBM62': 103,
#  '9.A.23': 102,
#  'CheD': 102,
#  'GH43_23': 102,
#  'GH121': 101,
#  'PL40': 101,
#  '2.A.101': 100,
#  '9.B.13': 99,
#  'GT70': 98,
#  '1.E.26': 98,
#  '1.E.22': 98,
#  'GH44': 98,
#  'GH139': 98,
#  'PL16': 97,
#  'CsrA': 97,
#  'GH5_28': 97,
#  '1.A.2': 97,
#  '1.B.50': 96,
#  'PL1_3': 96,
#  '1.A.63': 96,
#  'GH5_48': 95,
#  '1.A.28': 95,
#  'GH13_41': 95,
#  '1.A.10': 94,
#  'ROS_MUCR': 92,
#  'GH43_8': 92,
#  'GT42': 91,
#  'GH5_19': 90,
#  'HNOB': 90,
#  '9.B.75': 89,
#  '1.E.52': 89,
#  'GH43_27': 88,
#  'GH16_7': 88,
#  '9.B.70': 88,
#  'PL22_2': 88,
#  'Phage_AlpA': 88,
#  'PL2_2': 86,
#  '1.B.62': 86,
#  '9.B.73': 86,
#  'GH5_35': 86,
#  'GH161': 85,
#  'CBM27': 85,
#  'GH147': 85,
#  'PL9_3': 84,
#  '9.B.168': 84,
#  'PL22_1': 84,
#  'GT23': 83,
#  'AA5_2': 83,
#  'GH13_7': 83,
#  'PL7_3': 82,
#  'GH43_35': 82,
#  'GH98': 81,
#  'GH30': 81,
#  '1.E.5': 79,
#  '9.B.30': 79,
#  '1.K.4': 79,
#  '9.B.185': 79,
#  'GH143': 79,
#  'GH14': 79,
#  'CBM36': 79,
#  'MetJ': 78,
#  '1.C.65': 76,
#  'CBM11': 76,
#  '9.B.107': 76,
#  'GT82': 75,
#  '9.B.118': 75,
#  'YcbB': 75,
#  '9.A.10': 74,
#  '1.A.105': 74,
#  'PL6_2': 74,
#  '9.B.182': 73,
#  '1.A.17': 73,
#  '1.E.27': 72,
#  '1.B.79': 72,
#  'GH5_40': 72,
#  'GH13_6': 72,
#  '9.B.117': 71,
#  'GT92': 71,
#  '1.C.67': 71,
#  '9.A.31': 69,
#  'CBM70': 68,
#  'PL4_1': 68,
#  'GH16_24': 68,
#  '9.B.76': 67,
#  'GT45': 66,
#  '2.A.71': 66,
#  '3.D.8': 65,
#  '1.C.14': 64,
#  'HTH_CodY': 64,
#  '9.B.171': 64,
#  '9.A.36': 63,
#  'PL17_1': 62,
#  'GT100': 62,
#  '1.E.23': 61,
#  'FeS': 60,
#  'GH5_51': 60,
#  '1.E.20': 59,
#  'GH16_16': 59,
#  '8.A.58': 59,
#  '1.C.11': 58,
#  'GH43_33': 58,
#  'Ogr_Delta': 57,
#  'GT22': 55,
#  'GcrA': 55,
#  'GH71': 55,
#  '1.C.3': 54,
#  '1.E.29': 54,
#  'PL4_4': 54,
#  'GH43_37': 54,
#  'CBM59': 54,
#  '1.E.24': 53,
#  'PL10_2': 53,
#  'PL14_3': 53,
#  ...}

# %%
model = gensim.models.doc2vec.Doc2Vec(vector_size=150, min_count=5, epochs=50, workers = 7)

# %%
model.build_vocab(gene_list_tagged)

# %%
model.train(gene_list_tagged, total_examples=model.corpus_count, epochs=model.epochs)

# %%
model.dv.vectors
# Out:
# array([[-0.04359931, -0.12279987,  0.03364977, ...,  0.11158752,
#          0.08223165,  0.11421367],
#        [-0.08598403, -0.05462262, -0.15506236, ...,  0.04846105,
#          0.01435147, -0.00699653],
#        [ 1.095605  ,  0.43584013,  0.88834065, ..., -0.80106336,
#          0.08906978,  0.11257318],
#        ...,
#        [ 0.47429752, -0.08396782,  0.19070882, ...,  0.00834298,
#          0.05697758,  0.2318706 ],
#        [-0.06271408,  0.19763988,  0.10305916, ..., -0.20616344,
#         -0.24441129,  0.6949025 ],
#        [-0.4908523 , -0.31037715,  0.14895608, ..., -0.21469057,
#          0.3487398 , -0.01495322]], dtype=float32)

# %%
model.save("doc2vec_on_unsupervised.model")

# %%
model1 = gensim.models.doc2vec.Doc2Vec.load("doc2vec_on_unsupervised.model")

# %%
model1.dv.most_similar(model1.infer_vector(gene_list[0]))
# Out:
# [(215938, 0.8419824838638306),
#  (12401, 0.8281993865966797),
#  (220297, 0.8277339935302734),
#  (0, 0.8275951743125916),
#  (164923, 0.8259299993515015),
#  (235684, 0.8217179179191589),
#  (114747, 0.8209587335586548),
#  (16987, 0.8206168413162231),
#  (32022, 0.8166061043739319),
#  (199156, 0.8151360154151917)]

# %%
model1.wv.index_to_key
# Out:
# ['3.A.1',
#  '2.A.1',
#  'GT2',
#  'GT4',
#  'Response_reg',
#  'HTH_1',
#  'LysR_substrate',
#  'HATPase_c',
#  '1.B.14',
#  '2.A.6',
#  'HTH_18',
#  'LacI',
#  'Peripla_BP_3',
#  '3.D.1',
#  'GntR',
#  '3.A.23',
#  'HisKA',
#  '2.A.7',
#  'TetR_N',
#  '9.B.34',
#  'Aminotran_1_2',
#  '4.C.1',
#  '2.A.3',
#  '2.A.21',
#  'Trans_reg_C',
#  '1.B.52',
#  'GerE',
#  '4.A.3',
#  '9.B.18',
#  '4.A.1',
#  'GH23',
#  '3.A.6',
#  'PfkB',
#  'Pyr_redox_2',
#  '5.A.3',
#  '3.A.7',
#  'GH1',
#  '3.A.3',
#  'MarR',
#  'SBP_bac_1',
#  'GH3',
#  'AraC_binding',
#  '3.A.2',
#  '2.A.66',
#  '4.A.2',
#  '8.A.5',
#  'GT51',
#  'SIS',
#  '3.D.4',
#  'HTH_3',
#  '1.A.30',
#  '4.A.6',
#  'Sigma70_r2',
#  'GH2',
#  'CE4',
#  '2.A.56',
#  '3.A.15',
#  '8.A.3',
#  '2.A.2',
#  'PAS',
#  'CBM50',
#  'GT9',
#  'EAL',
#  'GT0',
#  'Sigma70_r4_2',
#  'NUDIX',
#  '3.A.5',
#  'Peripla_BP_1',
#  '2.A.23',
#  '8.A.59',
#  'CBM48',
#  '2.A.40',
#  'HTH_DeoR',
#  'Glyoxalase',
#  'GH73',
#  'GH32',
#  '1.A.23',
#  '8.A.1',
#  'GGDEF',
#  'MerR',
#  'HTH_IclR',
#  'CBM32',
#  'GH18',
#  'DeoRC',
#  'GH4',
#  '3.A.11',
#  'HTH_5',
#  '1.I.1',
#  '2.A.109',
#  'HTH_11',
#  'SBP_bac_3',
#  'GT35',
#  'CheW',
#  '9.B.97',
#  'PALP',
#  '3.A.9',
#  'HTH_6',
#  '2.A.63',
#  'GH31',
#  '2.A.53',
#  'Sigma70_r4',
#  '2.A.80',
#  'AA3_2',
#  'GT83',
#  '3.D.10',
#  '2.A.86',
#  'CbiA',
#  'GT1',
#  '9.B.146',
#  '1.B.18',
#  'CBS',
#  '2.A.76',
#  'CE9',
#  'HD',
#  'Rhodanese',
#  '2.A.8',
#  '1.B.1',
#  'Pribosyltran',
#  'Fer4',
#  'GH13_11',
#  '9.A.40',
#  'GH20',
#  '1.B.42',
#  'CBM13',
#  '8.A.46',
#  '2.A.36',
#  'GH13_9',
#  'IclR',
#  'dCache_1',
#  'GT5',
#  '3.B.1',
#  'cNMP_binding',
#  'GH77',
#  '9.B.27',
#  'AAA',
#  '9.B.106',
#  '2.A.37',
#  'TPR_2',
#  '2.A.42',
#  'GAF',
#  '2.A.4',
#  'LytTR',
#  'GT20',
#  'TPR_1',
#  'GH36',
#  '9.B.33',
#  '1.B.6',
#  'GH92',
#  '9.A.8',
#  'GH13_31',
#  '2.A.38',
#  'AsnC_trans_reg',
#  'GT26',
#  '2.A.102',
#  'CE1',
#  'GT28',
#  '2.A.103',
#  '2.A.15',
#  'CSD',
#  'GH103',
#  'Peripla_BP_2',
#  '9.B.14',
#  'MCPsignal',
#  '2.A.115',
#  '1.B.12',
#  '9.B.126',
#  'GH105',
#  '1.B.11',
#  'GH25',
#  'GH65',
#  'GH8',
#  '3.D.5',
#  '3.D.6',
#  '2.A.108',
#  'GT8',
#  'GH38',
#  'ACT',
#  '1.B.17',
#  'GH0',
#  '3.D.2',
#  'GH29',
#  'Nitroreductase',
#  '9.B.102',
#  '1.B.33',
#  '2.A.47',
#  '1.B.55',
#  'CBM2',
#  'GT30',
#  'GH15',
#  '4.A.7',
#  '9.B.10',
#  '2.A.122',
#  'FecR',
#  '5.A.1',
#  '3.A.18',
#  '1.A.1',
#  'GH42',
#  '1.A.33',
#  'GH28',
#  '9.B.20',
#  '2.A.39',
#  '3.A.16',
#  '1.E.14',
#  '2.A.49',
#  '1.A.35',
#  '2.A.25',
#  'CBM6',
#  '1.B.22',
#  '8.A.7',
#  '4.F.1',
#  'Pyr_redox',
#  '9.B.158',
#  'GH51',
#  '1.A.8',
#  'GH78',
#  'CheR',
#  '2.A.16',
#  'GH37',
#  '4.D.3',
#  '2.A.14',
#  'CheB_methylest',
#  'HhH-GPD',
#  'AA10',
#  '2.A.88',
#  'GH33',
#  '1.B.3',
#  '2.A.17',
#  'PadR',
#  'Mga',
#  '9.B.44',
#  '9.A.11',
#  'H-kinase_dim',
#  '2.A.13',
#  'Sigma70_r3',
#  '2.A.55',
#  '1.A.11',
#  'HxlR',
#  '2.A.41',
#  '2.A.20',
#  'CheR_N',
#  '9.B.186',
#  'CBM5',
#  'GH127',
#  '1.A.34',
#  '2.A.64',
#  '9.B.174',
#  'CE14',
#  'SpoIIE',
#  '2.A.114',
#  'GH13_19',
#  'GH16_3',
#  'GH13_10',
#  '9.B.160',
#  '2.A.98',
#  'GH10',
#  '2.A.85',
#  '1.A.26',
#  'CE11',
#  'HTH_8',
#  '8.A.21',
#  '9.B.169',
#  '9.B.104',
#  '2.A.35',
#  '3.D.7',
#  'GH94',
#  'FlhC',
#  '4.A.5',
#  'CBM67',
#  'Peptidase_M23',
#  'FlhD',
#  'CBM35',
#  '2.A.19',
#  '1.E.43',
#  'GH13_3',
#  '9.B.35',
#  '9.A.25',
#  '2.C.1',
#  'Y_Y_Y',
#  '2.A.95',
#  'GH13',
#  'Glucokinase',
#  '2.A.50',
#  'GH35',
#  '2.A.69',
#  '1.A.16',
#  'GH13_16',
#  '2.A.28',
#  'Rrf2',
#  'CE12',
#  'CheY-binding',
#  'GT19',
#  'NIR_SIR',
#  '9.B.157',
#  'NIR_SIR_ferr',
#  'PIG-L',
#  'GH88',
#  'GH13_26',
#  'GH39',
#  'CheZ',
#  'GH19',
#  'HMA',
#  'GH95',
#  'GT25',
#  'GH130',
#  '2.A.78',
#  '1.E.53',
#  'GH63',
#  '3.A.24',
#  '3.A.25',
#  '9.B.74',
#  '2.A.22',
#  'GH13_29',
#  '9.B.121',
#  'CE8',
#  '2.A.45',
#  '9.B.22',
#  '1.A.22',
#  'GT107',
#  '1.C.113',
#  'GH13_20',
#  'STAS',
#  'SKI',
#  '4.A.4',
#  'GH13_18',
#  '1.A.62',
#  'Reg_prop',
#  '9.B.62',
#  '9.B.105',
#  'Pkinase',
#  'GyrI-like',
#  'GH102',
#  'GH97',
#  'GH24',
#  '3.D.9',
#  'GH13_30',
#  'GT41',
#  '2.A.79',
#  '9.B.124',
#  'GH9',
#  '3.D.3',
#  '1.A.14',
#  'Crp',
#  '1.A.43',
#  '2.A.113',
#  '8.A.8',
#  'GH13_5',
#  'FUR',
#  'FHA',
#  'GT32',
#  'GH43_26',
#  '9.B.114',
#  'FeoA',
#  'GH26',
#  '9.B.32',
#  'CBM41',
#  'CBM34',
#  '2.A.26',
#  'GH125',
#  'GH53',
#  '1.B.25',
#  'CE7',
#  'GH154',
#  'B12-binding',
#  'EPSP_synthase',
#  '3.A.12',
#  'GT81',
#  '5.B.3',
#  'PL22',
#  'GH13_23',
#  'Fe_dep_repress',
#  'Autoind_bind',
#  '1.B.20',
#  '4.B.1',
#  'ANTAR',
#  '2.A.81',
#  '2.A.58',
#  '2.A.33',
#  '9.B.143',
#  '9.B.1',
#  '2.A.9',
#  '9.B.99',
#  'GATase_2',
#  'PTS-HPr',
#  'Citrate_synt',
#  '2.A.51',
#  '1.B.76',
#  '9.B.142',
#  '9.B.29',
#  '9.B.149',
#  'SBP_bac_5',
#  '1.C.75',
#  '2.A.27',
#  '9.A.41',
#  'CBM51',
#  'GH57',
#  'CE5',
#  'GH43_11',
#  'MASE1',
#  'TetR_C',
#  'GH27',
#  '9.B.28',
#  'GH153',
#  '3.A.4',
#  '2.A.5',
#  'GT87',
#  '1.B.40',
#  '8.A.28',
#  '2.A.89',
#  '1.A.46',
#  '1.A.104',
#  'GH13_14',
#  '1.A.12',
#  'GH6',
#  '9.B.100',
#  '2.A.59',
#  'GH13_13',
#  'CBM73',
#  '2.A.117',
#  '9.B.67',
#  '9.A.47',
#  '9.B.43',
#  '1.A.77',
#  'Fe_dep_repr_C',
#  '9.B.120',
#  '1.B.9',
#  'Hemerythrin',
#  '9.B.136',
#  'GH43_12',
#  'HTH_7',
#  'PspC',
#  'AA2',
#  'GH106',
#  '2.A.11',
#  'GH43_10',
#  'BTAD',
#  'NTP_transf_2',
#  '2.A.118',
#  'CBM66',
#  'GH146',
#  '2.A.72',
#  'TOBE',
#  '1.A.13',
#  'GT39',
#  '1.B.35',
#  '5.A.2',
#  '2.A.34',
#  'CBM3',
#  '2.A.121',
#  'GT84',
#  '1.C.82',
#  'GH144',
#  '8.A.4',
#  'GH74',
#  '2.A.107',
#  'TrmB',
#  '9.B.8',
#  '9.B.156',
#  '2.A.61',
#  'CBM4',
#  '2.A.123',
#  '9.B.153',
#  'CBM9',
#  'GH76',
#  '9.B.141',
#  '9.B.31',
#  'CBM12',
#  '9.B.36',
#  'PL1_2',
#  '3.E.2',
#  '2.A.46',
#  'GT111',
#  'AA6',
#  'GH109',
#  'GH68',
#  'GT14',
#  '5.B.1',
#  '9.B.2',
#  'GH141',
#  '8.A.43',
#  'PL11',
#  'CBM57',
#  '9.A.5',
#  '2.A.24',
#  '1.B.39',
#  'GT104',
#  '1.B.73',
#  '1.C.80',
#  '1.B.48',
#  'Glycos_trans_3N',
#  '2.A.75',
#  '1.E.34',
#  'AlkA_N',
#  'GH87',
#  'HEM4',
#  'CBM20',
#  'GT53',
#  'GH108',
#  '9.B.125',
#  'GH115',
#  'GH67',
#  'GH55',
#  '1.B.10',
#  '1.B.23',
#  '1.B.46',
#  'GH43_34',
#  'GT21',
#  'dCache_2',
#  '9.B.51',
#  '2.A.68',
#  'PL0',
#  'GH84',
#  '1.C.109',
#  'CBM22',
#  '9.B.42',
#  'CBM47',
#  '1.A.72',
#  'CBM38',
#  '1.B.15',
#  '4.D.1',
#  '1.E.40',
#  '2.A.10',
#  'GH30_3',
#  'Penicillinase_R',
#  'GH43_24',
#  '2.A.120',
#  '2.A.52',
#  '1.B.54',
#  '4.D.2',
#  'GH43_4',
#  'Ada_Zn_binding',
#  'Guanylate_cyc',
#  '9.B.72',
#  'GH43_29',
#  '9.A.4',
#  'CBM16',
#  'GH133',
#  'GH5_2',
#  '1.B.19',
#  'GT76',
#  '2.A.119',
#  '5.B.7',
#  '1.B.4',
#  'GH114',
#  '1.B.21',
#  'SpoVT_AbrB',
#  '9.B.55',
#  'Whib',
#  'GH85',
#  '2.A.106',
#  'GH13_21',
#  'GH5',
#  'ATPase_2',
#  '1.B.70',
#  '2.A.87',
#  'GH136',
#  'CBM61',
#  'TrkA_C',
#  'PL1_6',
#  'GH43_5',
#  '5.B.5',
#  'CBM42',
#  '2.A.96',
#  '9.B.65',
#  '2.A.67',
#  'GH16_21',
#  '9.B.144',
#  '9.B.4',
#  'GH166',
#  'Trp_repressor',
#  'GH17',
#  'DctP',
#  'GT56',
#  'GT11',
#  'CE0',
#  'CE2',
#  '9.B.211',
#  'PL8',
#  '9.B.176',
#  'GH16',
#  'PL38',
#  'B12-binding_2',
#  '1.C.105',
#  'GH140',
#  'GH13_32',
#  'GH117',
#  '1.C.57',
#  '3.A.10',
#  'GH43_22',
#  'Arg_repressor',
#  'AA3',
#  '1.A.78',
#  '8.B.24',
#  'GH13_36',
#  'GH13_4',
#  'PL1',
#  'GT73',
#  '9.B.145',
#  'GH113',
#  'CBM26',
#  '2.A.73',
#  'GH89',
#  'GH5_13',
#  'GH104',
#  'Diacid_rec',
#  'GH43_1',
#  '9.B.159',
#  'GH50',
#  '1.E.1',
#  'GH13_38',
#  'GH64',
#  'GH5_8',
#  '1.C.36',
#  'GH13_2',
#  'CE6',
#  'GH5_5',
#  '9.A.24',
#  'GH5_1',
#  '9.B.183',
#  'GH12',
#  'GT94',
#  '2.A.124',
#  '1.C.39',
#  '9.A.61',
#  'GH129',
#  'GH46',
#  '9.B.128',
#  'GT89',
#  'PL9',
#  'PL9_1',
#  '9.B.15',
#  '9.B.21',
#  'LexA_DNA_bind',
#  '1.M.1',
#  'FMN_bind_2',
#  'GH13_39',
#  'GH11',
#  '9.B.110',
#  '3.A.8',
#  '2.A.70',
#  '9.B.116',
#  'GH123',
#  'PL12',
#  'MHYT',
#  'GH5_4',
#  'GH5_41',
#  '9.B.12',
#  'PL9_2',
#  'GT27',
#  'PL26',
#  '9.B.172',
#  'PL7_1',
#  'CBM25',
#  'PL17',
#  'HTH_10',
#  '9.B.150',
#  'CE15',
#  'PL12_3',
#  'GH30_8',
#  '1.B.13',
#  '3.A.14',
#  '5.B.4',
#  'FmdA_AmdA',
#  'GH30_1',
#  'PL17_2',
#  '1.B.5',
#  '2.A.116',
#  'PL6',
#  'GH43_16',
#  'GH99',
#  'CHASE3',
#  'CBM69',
#  'GT101',
#  'CYTH',
#  'GH43_18',
#  '9.B.50',
#  '9.A.18',
#  '2.A.77',
#  'GH158',
#  'GH135',
#  'peroxidase',
#  '1.E.19',
#  '8.A.51',
#  'HTH_AraC',
#  'GH126',
#  'GH43_9',
#  'GT52',
#  'PL10_1',
#  '1.B.71',
#  'GH70',
#  '1.C.106',
#  'CE16',
#  'BLUF',
#  '2.A.62',
#  'Cyanate_lyase',
#  'GH5_18',
#  'GH62',
#  'GH116',
#  '9.B.111',
#  '1.B.66',
#  '1.B.77',
#  'GH101',
#  'GH48',
#  'CE3',
#  'GH91',
#  'HTH_Mga',
#  'GH112',
#  '1.E.2',
#  'GT66',
#  'SLH',
#  'GT85',
#  'PL33_1',
#  'GH13_33',
#  '8.A.2',
#  'FIST',
#  'GT108',
#  'PL6_1',
#  '1.A.4',
#  'GH30_5',
#  '1.B.44',
#  'GH43_3',
#  'AA7',
#  'GH81',
#  'GH13_27',
#  'CBM44',
#  'GH5_7',
#  'GH13_28',
#  'GH16_5',
#  'PL7_5',
#  'GT60',
#  'CBM54',
#  'GH5_25',
#  'GH43_28',
#  '3.A.20',
#  '9.B.115',
#  'SBP_bac_10',
#  'GH145',
#  'CheC',
#  '2.A.83',
#  '3.A.17',
#  '2.A.111',
#  'Arc',
#  '1.A.45',
#  'GH110',
#  'Nitro_FeMo-Co',
#  'CBM63',
#  '9.B.164',
#  '1.C.1',
#  'TPR_4',
#  '1.A.29',
#  'PSK_trans_fac',
#  'PglZ',
#  '3.E.1',
#  'PL5_1',
#  'GT10',
#  '9.A.21',
#  '1.E.31',
#  'PL1_5',
#  '8.A.48',
#  'TPR_3',
#  'GH30_2',
#  'GH30_4',
#  'PHY',
#  '1.B.57',
#  '9.B.69',
#  'CBM46',
#  '9.B.96',
#  'GH93',
#  'GH148',
#  '2.A.104',
#  '1.C.107',
#  'NIT',
#  '1.A.25',
#  '9.B.209',
#  'CBM56',
#  'AA5',
#  'GH5_46',
#  'PL8_2',
#  '1.A.54',
#  '9.B.140',
#  'PL11_1',
#  'GH120',
#  'GH43_19',
#  'GT44',
#  'ArsD',
#  'GH163',
#  'PL12_1',
#  'GH43_17',
#  'GH142',
#  'PL3_1',
#  'SirB',
#  '8.A.79',
#  'GH66',
#  '1.E.11',
#  'GH13_8',
#  '9.B.52',
#  'GH100',
#  '9.B.46',
#  'CHASE4',
#  'PL8_3',
#  '4.C.3',
#  'GT3',
#  'CHASE',
#  'PL1_8',
#  'PL29',
#  'GH43_2',
#  'GH13_12',
#  '9.B.179',
#  '9.B.196',
#  'GH59',
#  'cohesin',
#  'GH165',
#  'GH5_44',
#  'PL2_1',
#  'HTH_12',
#  '8.A.35',
#  'GH151',
#  'GH13_1',
#  'GH128',
#  'HEAT_PBS',
#  '1.C.98',
#  'bZIP_1',
#  'PL7',
#  'GH79',
#  'RseA_N',
#  '1.B.27',
#  '1.E.56',
#  '1.E.54',
#  '9.B.127',
#  'GH54',
#  'PL3_4',
#  '9.A.55',
#  'CBM40',
#  'CBM71',
#  'HTH_psq',
#  'PL5',
#  '1.B.26',
#  '9.B.98',
#  'Sigma70_ECF',
#  'CBM23',
#  'GH43',
#  'GH43_31',
#  '1.A.87',
#  'GT17',
#  '1.C.12',
#  '2.A.12',
#  'AA4',
#  '1.C.10',
#  'PL31',
#  'GH43_30',
#  '1.C.72',
#  'Fez1',
#  'GH43_32',
#  'PL33_2',
#  'GH13_42',
#  'CBM68',
#  'GT102',
#  '2.A.99',
#  '9.A.28',
#  '9.A.39',
#  '9.B.85',
#  'CtsR',
#  'SfsA',
#  'GH137',
#  'GH86',
#  '1.B.16',
#  'PL35',
#  '1.C.41',
#  'CHASE2',
#  '1.B.81',
#  '9.A.15',
#  'GH75',
#  'PL8_1',
#  'GH138',
#  'GH5_39',
#  '1.B.68',
#  'GH13_37',
#  '1.E.55',
#  'GH159',
#  'HHA',
#  '9.B.148',
#  'GH149',
#  '1.A.6',
#  '1.B.75',
#  '9.B.155',
#  'GH16_9',
#  'GH52',
#  'CBM62',
#  '9.B.24',
#  'GH43_23',
#  '9.A.23',
#  'CheD',
#  'PL40',
#  'GH121',
#  '2.A.101',
#  '9.B.13',
#  'GT70',
#  'GH139',
#  'GH44',
#  '1.E.22',
#  '1.E.26',
#  'GH5_28',
#  'PL16',
#  '1.A.2',
#  'CsrA',
#  '1.B.50',
#  'PL1_3',
#  '1.A.63',
#  '1.A.28',
#  'GH13_41',
#  'GH5_48',
#  '1.A.10',
#  'ROS_MUCR',
#  'GH43_8',
#  'GT42',
#  'GH5_19',
#  'HNOB',
#  '1.E.52',
#  '9.B.75',
#  'GH16_7',
#  'Phage_AlpA',
#  'PL22_2',
#  '9.B.70',
#  'GH43_27',
#  '1.B.62',
#  '9.B.73',
#  'PL2_2',
#  'GH5_35',
#  'GH161',
#  'CBM27',
#  'GH147',
#  'PL9_3',
#  'PL22_1',
#  '9.B.168',
#  'GT23',
#  'AA5_2',
#  'GH13_7',
#  'PL7_3',
#  'GH43_35',
#  'GH98',
#  'GH30',
#  'GH14',
#  'GH143',
#  'CBM36',
#  '9.B.30',
#  '1.E.5',
#  '9.B.185',
#  '1.K.4',
#  'MetJ',
#  '1.C.65',
#  '9.B.107',
#  'CBM11',
#  'GT82',
#  '9.B.118',
#  'YcbB',
#  '9.A.10',
#  'PL6_2',
#  '1.A.105',
#  '1.A.17',
#  '9.B.182',
#  '1.E.27',
#  'GH5_40',
#  '1.B.79',
#  'GH13_6',
#  'GT92',
#  '1.C.67',
#  '9.B.117',
#  '9.A.31',
#  'CBM70',
#  'GH16_24',
#  'PL4_1',
#  '9.B.76',
#  'GT45',
#  '2.A.71',
#  '3.D.8',
#  'HTH_CodY',
#  '1.C.14',
#  '9.B.171',
#  '9.A.36',
#  'PL17_1',
#  'GT100',
#  '1.E.23',
#  'GH5_51',
#  'FeS',
#  'GH16_16',
#  '1.E.20',
#  '8.A.58',
#  'GH43_33',
#  '1.C.11',
#  'Ogr_Delta',
#  'GT22',
#  'GcrA',
#  'GH71',
#  'CBM59',
#  'GH43_37',
#  '1.E.29',
#  '1.C.3',
#  'PL4_4',
#  'GH5_21',
#  'PL15_1',
#  'PL10_2',
#  ...]

# %%
model.infer_vector(["GH16"])
# Out:
# array([-7.91745037e-02, -4.54938561e-02,  9.59275756e-04,  8.47191140e-02,
#        -7.21042305e-02,  6.15637191e-02,  7.52093941e-02, -7.98927248e-02,
#         1.18389279e-02,  4.55212779e-03,  1.34841790e-02,  1.58867352e-02,
#         1.93221554e-01, -1.06945023e-01,  1.41923572e-03, -1.59381285e-01,
#        -7.67338499e-02,  7.65968934e-02, -1.00356294e-02,  8.80025849e-02,
#         6.95675090e-02,  4.94618602e-02, -2.67843548e-02,  9.66396406e-02,
#         4.85779904e-02,  8.95073116e-02,  1.39114723e-01, -7.12695299e-03,
#        -1.76635444e-01, -4.09763977e-02, -5.52057363e-02, -1.56720821e-02,
#         8.61614794e-02, -5.90439811e-02,  1.12519655e-02, -1.10590905e-01,
#         2.81033907e-02,  4.14217450e-02,  1.25915721e-01,  7.16576912e-03,
#         4.31902111e-02,  3.89410406e-02, -9.47081670e-03, -6.36899620e-02,
#        -8.31664130e-02,  1.05808914e-01, -4.62713428e-02,  1.98927402e-01,
#        -1.90148205e-01,  8.64318088e-02,  2.27443948e-01,  4.94409241e-02,
#         1.32712319e-01,  1.18874356e-01,  6.39737397e-02,  7.23374933e-02,
#        -2.85992585e-02,  1.68394849e-01, -2.36606337e-02,  8.15894306e-02,
#        -3.38766910e-02,  7.53822923e-02, -4.61150892e-02,  8.48845094e-02,
#        -7.10774139e-02,  1.51314855e-01, -1.07595615e-01, -8.17664340e-02,
#         2.99197845e-02,  1.33110385e-03,  5.63317388e-02,  1.11960493e-01,
#         1.54909668e-02,  1.24627613e-01,  2.28507388e-02,  4.56914417e-02,
#         1.00462204e-02,  1.07978866e-01,  4.63479795e-02, -4.91545871e-02,
#         8.25348217e-03, -6.95236623e-02, -1.38282672e-01, -4.80446257e-02,
#         7.70497927e-03,  1.04967877e-02, -5.62710613e-02,  3.02178469e-02,
#         1.03042079e-02, -1.20987529e-02,  1.55430324e-02, -2.53090579e-02,
#        -2.17312593e-02, -4.31250297e-02,  6.77964613e-02,  3.11066955e-02,
#        -9.50508267e-02, -3.48994210e-02,  5.79754338e-02, -7.76418746e-02,
#        -1.26579508e-01,  8.98013916e-03, -1.09023020e-01, -3.03948857e-02,
#        -1.41640708e-01, -3.44503745e-02,  3.48732769e-02,  7.04976171e-02,
#         6.48912564e-02, -5.71513660e-02,  8.01512524e-02, -1.58259142e-02,
#        -3.04680951e-02, -8.10296237e-02,  2.55583283e-02,  9.40707400e-02,
#        -7.74910152e-02,  5.10771684e-02, -4.24031876e-02,  1.02993220e-01,
#         4.34345985e-03, -4.84255627e-02, -2.49516200e-02,  7.85388723e-02,
#        -3.40235494e-02,  7.80306570e-03, -2.11355444e-02, -4.75195125e-02,
#        -1.05705723e-01, -9.16315466e-02,  9.64983404e-02, -4.11733091e-02,
#         3.95764299e-02,  1.66906267e-01,  3.19045298e-02, -2.02282984e-02,
#        -8.77999142e-02,  6.24438180e-05, -6.22963943e-02, -4.08579446e-02,
#        -8.39625672e-02, -1.71985820e-01,  2.66277120e-02,  1.66280612e-01,
#         7.00992765e-03,  1.25410501e-02,  4.65758555e-02,  1.57031603e-02,
#        -1.21968668e-02,  1.60835907e-01], dtype=float32)
